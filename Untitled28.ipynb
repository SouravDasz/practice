# %% [markdown]
# <a href="https://colab.research.google.com/github/SouravDasz/practice/blob/main/Untitled28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/shopping_behavior_updated.csv")

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %% [markdown]
# # colums type
# - Numerical = 'Age','Purchase Amount (USD)','Size','Review Rating','Previous Purchases'
#
# - Catagorical = Gender,Item Purchased ,Catagory,Location ,Color,Season,Discount Applied ,Promocode Used,Payment Method ,Frequency of Purchases

# %% [markdown]
# # Age
# **conclusion**
# - The age colums is normaly distrybuted
# - max age is 70 and min is 18

# %%
df["Age"].describe()
# Out:
# count    3900.000000
# mean       44.068462
# std        15.207589
# min        18.000000
# 25%        31.000000
# 50%        44.000000
# 75%        57.000000
# max        70.000000
# Name: Age, dtype: float64

# %%
sns.histplot(x=df["Age"])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df["Age"].skew()
# Out:
# np.float64(-0.0063797217209905395)

# %% [markdown]
# # perchase Amount
# **conclusion**
# - This colums is also normaly distrybuted
# - No outlier is founded

# %%
df["Purchase Amount (USD)"].describe()
# Out:
# count    3900.000000
# mean       59.764359
# std        23.685392
# min        20.000000
# 25%        39.000000
# 50%        60.000000
# 75%        81.000000
# max       100.000000
# Name: Purchase Amount (USD), dtype: float64

# %%
sns.histplot(x=df["Purchase Amount (USD)"])
# Out:
# <Axes: xlabel='Purchase Amount (USD)', ylabel='Count'>

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df["Review Rating"].describe()
# Out:
# count    3900.000000
# mean        3.749949
# std         0.716223
# min         2.500000
# 25%         3.100000
# 50%         3.700000
# 75%         4.400000
# max         5.000000
# Name: Review Rating, dtype: float64

# %%
df['Review Rating'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Univarient analysis of catagorical column

# %% [markdown]
# # Gender
# **conclusion**
# - Number of male is double then Women

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      2652
# Female    1248
# Name: count, dtype: int64

# %%
sns.countplot(x=df["Gender"],palette="viridis")
# Out:
# /tmp/ipython-input-486237423.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["Gender"],palette="viridis")
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df["Item Purchased"].value_counts()
# Out:
# Item Purchased
# Blouse        171
# Pants         171
# Jewelry       171
# Shirt         169
# Dress         166
# Sweater       164
# Jacket        163
# Coat          161
# Sunglasses    161
# Belt          161
# Sandals       160
# Socks         159
# Skirt         158
# Scarf         157
# Shorts        157
# Hat           154
# Handbag       153
# Hoodie        151
# Shoes         150
# T-shirt       147
# Sneakers      145
# Boots         144
# Backpack      143
# Gloves        140
# Jeans         124
# Name: count, dtype: int64

# %% [markdown]
# # Categories
# **conclusion**
# - As we see most of the categories are Clothing and Accessories

# %%
df["Category"].value_counts()
# Out:
# Category
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: count, dtype: int64

# %%
sns.countplot(x=df["Category"],palette="viridis")
# Out:
# /tmp/ipython-input-3548290062.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["Category"],palette="viridis")
# <Axes: xlabel='Category', ylabel='count'>

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df["Location"].unique()
# Out:
# array(['Kentucky', 'Maine', 'Massachusetts', 'Rhode Island', 'Oregon',
#        'Wyoming', 'Montana', 'Louisiana', 'West Virginia', 'Missouri',
#        'Arkansas', 'Hawaii', 'Delaware', 'New Hampshire', 'New York',
#        'Alabama', 'Mississippi', 'North Carolina', 'California',
#        'Oklahoma', 'Florida', 'Texas', 'Nevada', 'Kansas', 'Colorado',
#        'North Dakota', 'Illinois', 'Indiana', 'Arizona', 'Alaska',
#        'Tennessee', 'Ohio', 'New Jersey', 'Maryland', 'Vermont',
#        'New Mexico', 'South Carolina', 'Idaho', 'Pennsylvania',
#        'Connecticut', 'Utah', 'Virginia', 'Georgia', 'Nebraska', 'Iowa',
#        'South Dakota', 'Minnesota', 'Washington', 'Wisconsin', 'Michigan'],
#       dtype=object)

# %%
df["Location"].value_counts().plot(kind="bar", figsize=(15, 10))
# Out:
# <Axes: xlabel='Location'>

# %% [markdown]
# # Size
# **conslusion**
# - Most of the people are not over sized;
# - M size is the most frequent value

# %%
df["Size"].value_counts()
# Out:
# Size
# M     1755
# L     1053
# S      663
# XL     429
# Name: count, dtype: int64

# %%
sns.countplot(x=df["Size"],palette="viridis")
# Out:
# /tmp/ipython-input-2084898438.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["Size"],palette="viridis")
# <Axes: xlabel='Size', ylabel='count'>

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# # color
# **conclusion**
# - There are too many colors and no one is over leading means they are not baised for colors

# %%
df["Color"].value_counts()
# Out:
# Color
# Olive        177
# Yellow       174
# Silver       173
# Teal         172
# Green        169
# Black        167
# Cyan         166
# Violet       166
# Gray         159
# Maroon       158
# Orange       154
# Charcoal     153
# Pink         153
# Blue         152
# Magenta      152
# Purple       151
# Peach        149
# Red          148
# Beige        147
# Indigo       147
# Lavender     147
# Turquoise    145
# White        142
# Brown        141
# Gold         138
# Name: count, dtype: int64

# %% [markdown]
# # Season
# **conclusion**
# - There is no seasonal hype

# %%
df["Season"].value_counts()
# Out:
# Season
# Spring    999
# Fall      975
# Winter    971
# Summer    955
# Name: count, dtype: int64
