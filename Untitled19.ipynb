# %% [markdown]
# <a href="https://colab.research.google.com/github/SouravDasz/practice/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/credit_card_fraud_dataset.csv")

# %%
df.head()
# Out:
#    TransactionID             TransactionDate   Amount  MerchantID  \
# 0              1  2024-04-03 14:15:35.462794  4189.27         688
# 1              2  2024-03-19 13:20:35.462824  2659.71         109
# 2              3  2024-01-08 10:08:35.462834   784.00         394
# 3              4  2024-04-13 23:50:35.462850  3514.40         944
# 4              5  2024-07-12 18:51:35.462858   369.07         475
#
#   TransactionType      Location  IsFraud
# 0          refund   San Antonio        0
# 1          refund        Dallas        0
# 2        purchase      New York        0
# 3        purchase  Philadelphia        0
# 4        purchase       Phoenix        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   TransactionID    100000 non-null  int64
#  1   TransactionDate  100000 non-null  object
#  2   Amount           100000 non-null  float64
#  3   MerchantID       100000 non-null  int64
#  4   TransactionType  100000 non-null  object
#  5   Location         100000 non-null  object
#  6   IsFraud          100000 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 5.3+ MB

# %%
df.shape
# Out:
# (100000, 7)

# %%
df["IsFraud"].value_counts()
# Out:
# IsFraud
# 0    99000
# 1     1000
# Name: count, dtype: int64

# %%
froud=df[df["IsFraud"]==1]

# %%
froud.head()
# Out:
#      TransactionID             TransactionDate   Amount  MerchantID  \
# 190            191  2024-09-07 18:24:35.463748  1703.80         916
# 191            192  2024-04-27 01:48:35.463751  4248.10         862
# 208            209  2023-11-05 01:05:35.463826  1641.32         826
# 319            320  2024-06-16 18:30:35.464289   281.18         237
# 370            371  2023-10-29 04:09:35.464522  3047.66         789
#
#     TransactionType      Location  IsFraud
# 190        purchase      San Jose        1
# 191        purchase      San Jose        1
# 208        purchase      San Jose        1
# 319        purchase  Philadelphia        1
# 370        purchase      New York        1

# %%
import datetime as dt
df["TransactionDate"]=pd.to_datetime(df["TransactionDate"])
df["year"]=df["TransactionDate"].dt.year

# %%
df["year"].value_counts()
# Out:
# year
# 2024    80449
# 2023    19551
# Name: count, dtype: int64

# %%
df["months"]=df["TransactionDate"].dt.month_name()

# %%
df.head()
# Out:
#    TransactionID            TransactionDate   Amount  MerchantID  \
# 0              1 2024-04-03 14:15:35.462794  4189.27         688
# 1              2 2024-03-19 13:20:35.462824  2659.71         109
# 2              3 2024-01-08 10:08:35.462834   784.00         394
# 3              4 2024-04-13 23:50:35.462850  3514.40         944
# 4              5 2024-07-12 18:51:35.462858   369.07         475
#
#   TransactionType      Location  IsFraud  year   months
# 0          refund   San Antonio        0  2024    April
# 1          refund        Dallas        0  2024    March
# 2        purchase      New York        0  2024  January
# 3        purchase  Philadelphia        0  2024    April
# 4        purchase       Phoenix        0  2024     July

# %%
sns.countplot(x=df["IsFraud"],hue=df["months"])
# Out:
# <Axes: xlabel='IsFraud', ylabel='count'>

# %%
df.head()
# Out:
#    TransactionID            TransactionDate   Amount  MerchantID  \
# 0              1 2024-04-03 14:15:35.462794  4189.27         688
# 1              2 2024-03-19 13:20:35.462824  2659.71         109
# 2              3 2024-01-08 10:08:35.462834   784.00         394
# 3              4 2024-04-13 23:50:35.462850  3514.40         944
# 4              5 2024-07-12 18:51:35.462858   369.07         475
#
#   TransactionType      Location  IsFraud  year   months
# 0          refund   San Antonio        0  2024    April
# 1          refund        Dallas        0  2024    March
# 2        purchase      New York        0  2024  January
# 3        purchase  Philadelphia        0  2024    April
# 4        purchase       Phoenix        0  2024     July

# %%
df.drop(["TransactionID","TransactionDate"],axis=1,inplace=True)

# %%
df.head()
# Out:
#     Amount  MerchantID TransactionType      Location  IsFraud  year   months
# 0  4189.27         688          refund   San Antonio        0  2024    April
# 1  2659.71         109          refund        Dallas        0  2024    March
# 2   784.00         394        purchase      New York        0  2024  January
# 3  3514.40         944        purchase  Philadelphia        0  2024    April
# 4   369.07         475        purchase       Phoenix        0  2024     July

# %%
froud["MerchantID"].unique()
# Out:
# array([ 916,  862,  826,  237,  789,  358,  588,  851,  492,  878,  713,
#         556,  866,  709,  778,  244,  841,  295,  902,  696,    6,  256,
#         240,  827,  860,  132,  951,  241,  964,  494,  635,  836,  162,
#         440,   59,  597,   17,  417,  382,   63,  144,  729,  766,  346,
#         639,  461,  263,  120,  747,  808,  568,  855,  462,   69,  659,
#         868,  698,  367,  277,  477,  280,  209,  222,  630,  525,  935,
#         762,  965,   57,  304,  213,  493,  436,  574,  548,  135,  288,
#         657,  538,  640,  890,  370,  441,  539,  311,  101,  661,  470,
#         472,  322,  941,  650,  886,  559,  605,  500,  914,  204,  582,
#         620,  176,  540,  933,  695,  986,    4,  662,  734,  725,  389,
#         607,  602,  276,  526,  772,  937,  127,  187,  475,  278,   25,
#          29,  504,  505,  600,  169,  507,  742,   55,  353,  340,  355,
#         900,  156,  306,  390,  481,  315,  160,  720,  906,  959,  451,
# ...

# %%
df.drop("MerchantID",axis=1,inplace=True)

# %%
df.head()
# Out:
#     Amount TransactionType      Location  IsFraud  year   months
# 0  4189.27          refund   San Antonio        0  2024    April
# 1  2659.71          refund        Dallas        0  2024    March
# 2   784.00        purchase      New York        0  2024  January
# 3  3514.40        purchase  Philadelphia        0  2024    April
# 4   369.07        purchase       Phoenix        0  2024     July

# %%
froud.head()
# Out:
#      TransactionID             TransactionDate   Amount  MerchantID  \
# 190            191  2024-09-07 18:24:35.463748  1703.80         916
# 191            192  2024-04-27 01:48:35.463751  4248.10         862
# 208            209  2023-11-05 01:05:35.463826  1641.32         826
# 319            320  2024-06-16 18:30:35.464289   281.18         237
# 370            371  2023-10-29 04:09:35.464522  3047.66         789
#
#     TransactionType      Location  IsFraud
# 190        purchase      San Jose        1
# 191        purchase      San Jose        1
# 208        purchase      San Jose        1
# 319        purchase  Philadelphia        1
# 370        purchase      New York        1

# %%
sns.countplot(x=df["TransactionType"],hue=df["IsFraud"])
# Out:
# <Axes: xlabel='TransactionType', ylabel='count'>

# %%
df.head()
# Out:
#     Amount TransactionType      Location  IsFraud  year   months
# 0  4189.27          refund   San Antonio        0  2024    April
# 1  2659.71          refund        Dallas        0  2024    March
# 2   784.00        purchase      New York        0  2024  January
# 3  3514.40        purchase  Philadelphia        0  2024    April
# 4   369.07        purchase       Phoenix        0  2024     July

# %%
df.iloc[:,2].unique()
# Out:
# array(['San Antonio', 'Dallas', 'New York', 'Philadelphia', 'Phoenix',
#        'Chicago', 'San Jose', 'San Diego', 'Houston', 'Los Angeles'],
#       dtype=object)

# %%
sns.countplot(x=df["Location"],hue=df["IsFraud"])
# Out:
# <Axes: xlabel='Location', ylabel='count'>
