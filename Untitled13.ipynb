# %% [markdown]
# <a href="https://colab.research.google.com/github/SouravDasz/practice/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from tensorflow import keras

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

iris=load_iris()
dara=iris.data
target=iris.target
x_train,x_test,y_train,y_test=train_test_split(dara,target,test_size=0.2,random_state=42)

# %%
model = Sequential([
    Dense(16, activation="relu"),
    Dense(8, activation="relu"),
    Dense(3, activation="softmax")   # 3 classes
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)


histry=model.fit(x_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.3612 - loss: 2.6715
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3456 - loss: 2.5654
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3519 - loss: 2.3493
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3019 - loss: 2.2992
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3123 - loss: 2.1207
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3435 - loss: 1.7704
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3321 - loss: 1.6754
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3342 - loss: 1.4888
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2810 - loss: 1.4205
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3363 - loss: 1.1932
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3498 - loss: 1.0667
# Epoch 12/100
# ...

# %%
import matplotlib.pyplot as plt

# Plot training accuracy and loss
plt.figure(figsize=(12, 5))

# Plot accuracy
plt.subplot(1, 2, 1) # 1 row, 2 columns, first plot
plt.plot(histry.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot loss
plt.subplot(1, 2, 2) # 1 row, 2 columns, second plot
plt.plot(histry.history['loss'], label='Training Loss')
plt.title('Training Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
model.fit(x_train,y_train,epochs=40)
# Out:
# Epoch 1/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9819 - loss: 0.2587
# Epoch 2/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9912 - loss: 0.2301
# Epoch 3/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9860 - loss: 0.2341
# Epoch 4/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9767 - loss: 0.2383
# Epoch 5/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9881 - loss: 0.2262
# Epoch 6/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9819 - loss: 0.2237
# Epoch 7/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9881 - loss: 0.2354
# Epoch 8/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9829 - loss: 0.2345
# Epoch 9/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9829 - loss: 0.2120
# Epoch 10/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9881 - loss: 0.2124
# Epoch 11/40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9767 - loss: 0.2213
# Epoch 12/40
# ...

# %%
from sklearn.metrics import accuracy_score
y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)
acc = accuracy_score(y_test, y_pred)
print("Accuracy:", acc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Accuracy: 0.9666666666666667

# %%
y_pred
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 2, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %%
y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)
print(y_pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# [1 0 2 1 1 0 1 2 2 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]

# %%
y_pred
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 2, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0])
