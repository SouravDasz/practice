# %% [markdown]
# <a href="https://colab.research.google.com/github/SouravDasz/practice/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/AI_Data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0             Name       Roll No Program Branch  Semester  \
# 0           0   AAKASH PIPALDE  0403AL231001  B.Tech     AL         4
# 1           1     AAYUSH PATEL  0403AL231002  B.Tech     AL         4
# 2           3      ABIR SAXENA  0403AL231004  B.Tech     AL         4
# 3           4  AMEY BHOKARIKAR  0403AL231005  B.Tech     AL         4
# 4           7      ANTIM JAMLE  0403AL231008  B.Tech     AL         4
#
#     Status    Session AL401- [T] AL402- [T] AL403- [P] AL404- [P] AL405- [P]  \
# 0  Regular  June-2025         C+          B          A          A          A
# 1  Regular  June-2025          B          B          B          B          B
# 2  Regular  June-2025          D          C          B          B          B
# 3  Regular  June-2025          C          B          A          A          A
# 4  Regular  June-2025          F         C+         B+         B+         B+
#
#   AL406- [P] Result Description  SGPA  CGPA
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0  Semester       SGPA       CGPA
# count   62.000000      62.0  62.000000  62.000000
# mean    38.822581       4.0   6.605806   6.547903
# std     22.654587       0.0   1.048886   0.888833
# min      0.000000       4.0   3.080000   3.570000
# 25%     19.250000       4.0   6.020000   5.882500
# 50%     38.000000       4.0   6.790000   6.705000
# 75%     58.750000       4.0   7.330000   7.240000
# max     77.000000       4.0   8.250000   8.070000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          62 non-null     int64
#  1   Name                62 non-null     object
#  2   Roll No             62 non-null     object
#  3   Program             62 non-null     object
#  4   Branch              62 non-null     object
#  5   Semester            62 non-null     int64
#  6   Status              62 non-null     object
#  7   Session             62 non-null     object
#  8   AL401- [T]          62 non-null     object
#  9   AL402- [T]          62 non-null     object
#  10  AL403- [P]          62 non-null     object
#  11  AL404- [P]          62 non-null     object
#  12  AL405- [P]          62 non-null     object
#  13  AL406- [P]          62 non-null     object
#  14  Result Description  62 non-null     object
# ...

# %%
df.shape
# Out:
# (62, 17)

# %%
df.drop(["Roll No","Name","Unnamed: 0"],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Program Branch  Semester   Status    Session AL401- [T] AL402- [T]  \
# 0  B.Tech     AL         4  Regular  June-2025         C+          B
# 1  B.Tech     AL         4  Regular  June-2025          B          B
# 2  B.Tech     AL         4  Regular  June-2025          D          C
# 3  B.Tech     AL         4  Regular  June-2025          C          B
# 4  B.Tech     AL         4  Regular  June-2025          F         C+
#
#   AL403- [P] AL404- [P] AL405- [P] AL406- [P] Result Description  SGPA  CGPA
# 0          A          A          A          A               PASS  7.08  6.71
# 1          B          B          B          B               PASS  6.46  6.38
# 2          B          B          B          B    PASS WITH GRACE  5.38  5.50
# 3          A          A          A          A    PASS WITH GRACE  6.71  6.82
# 4         B+         B+         B+         B+      Fail in AL401  5.33  5.29

# %%
df["Program"].value_counts()
# Out:
# Program
# B.Tech    62
# Name: count, dtype: int64

# %%
df['Branch'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Branch'>

# %%
df['Semester'].value_counts()
# Out:
# Semester
# 4    62
# Name: count, dtype: int64

# %%
df["Status"].value_counts()
# Out:
# Status
# Regular    62
# Name: count, dtype: int64

# %%
df.drop(["Program","Branch",'Semester','Status','Session'	],axis=1,inplace=True)

# %%
df.head()
# Out:
#   AL401- [T] AL402- [T] AL403- [P] AL404- [P] AL405- [P] AL406- [P]  \
# 0         C+          B          A          A          A          A
# 1          B          B          B          B          B          B
# 2          D          C          B          B          B          B
# 3          C          B          A          A          A          A
# 4          F         C+         B+         B+         B+         B+
#
#   Result Description  SGPA  CGPA
# 0               PASS  7.08  6.71
# 1               PASS  6.46  6.38
# 2    PASS WITH GRACE  5.38  5.50
# 3    PASS WITH GRACE  6.71  6.82
# 4      Fail in AL401  5.33  5.29

# %%
s404=df.iloc[:,0].value_counts()

# %%
sns.countplot(x=df['AL401- [T]'],palette="viridis")
# Out:
# /tmp/ipython-input-253232432.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['AL401- [T]'],palette="viridis")
# <Axes: xlabel='AL401- [T]', ylabel='count'>

# %%
sns.countplot(x=df['AL402- [T]'],palette="viridis")
# Out:
# /tmp/ipython-input-1159945908.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['AL402- [T]'],palette="viridis")
# <Axes: xlabel='AL402- [T]', ylabel='count'>

# %%
sns.countplot(x=df['AL403- [P]'],palette="viridis")
# Out:
# /tmp/ipython-input-1717529435.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['AL403- [P]'],palette="viridis")
# <Axes: xlabel='AL403- [P]', ylabel='count'>

# %%
sns.countplot(x=df['AL404- [P]'],palette="viridis")
# Out:
# /tmp/ipython-input-2716535658.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['AL404- [P]'],palette="viridis")
# <Axes: xlabel='AL404- [P]', ylabel='count'>

# %%
sns.countplot(x=df['AL405- [P]'],palette="viridis")
# Out:
# /tmp/ipython-input-1472704380.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['AL405- [P]'],palette="viridis")
# <Axes: xlabel='AL405- [P]', ylabel='count'>

# %%
sns.countplot(x=df['AL405- [P]'],palette="viridis")
# Out:
# /tmp/ipython-input-1472704380.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['AL405- [P]'],palette="viridis")
# <Axes: xlabel='AL405- [P]', ylabel='count'>

# %%
sns.countplot(x=df['AL406- [P]'],palette="viridis")
# Out:
# /tmp/ipython-input-879413997.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['AL406- [P]'],palette="viridis")
# <Axes: xlabel='AL406- [P]', ylabel='count'>

# %%
df['Result Description'].value_counts()
# Out:
# Result Description
# PASS                         48
# PASS WITH GRACE               6
# Fail in AL401                 5
# Fail in AL401,AL402,AL405     2
# Fail in AL405                 1
# Name: count, dtype: int64

# %%
sns.countplot(df["Result Description"],palette="viridis")
# Out:
# /tmp/ipython-input-1005697581.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df["Result Description"],palette="viridis")
# <Axes: xlabel='count', ylabel='Result Description'>

# %%
df.head()
# Out:
#   AL401- [T] AL402- [T] AL403- [P] AL404- [P] AL405- [P] AL406- [P]  \
# 0         C+          B          A          A          A          A
# 1          B          B          B          B          B          B
# 2          D          C          B          B          B          B
# 3          C          B          A          A          A          A
# 4          F         C+         B+         B+         B+         B+
#
#   Result Description  SGPA  CGPA
# 0               PASS  7.08  6.71
# 1               PASS  6.46  6.38
# 2    PASS WITH GRACE  5.38  5.50
# 3    PASS WITH GRACE  6.71  6.82
# 4      Fail in AL401  5.33  5.29

# %%
sns.histplot(df['SGPA'], kde=True, palette="viridis")
# Out:
# /tmp/ipython-input-1948178819.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['SGPA'], kde=True, palette="viridis")
# <Axes: xlabel='SGPA', ylabel='Count'>

# %%
df['SGPA'].describe()
# Out:
# count    62.000000
# mean      6.605806
# std       1.048886
# min       3.080000
# 25%       6.020000
# 50%       6.790000
# 75%       7.330000
# max       8.250000
# Name: SGPA, dtype: float64

# %%
sns.histplot(df['CGPA'], kde=True, palette="viridis")
# Out:
# /tmp/ipython-input-1714411392.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['CGPA'], kde=True, palette="viridis")
# <Axes: xlabel='CGPA', ylabel='Count'>

# %%
plt.figure(figsize=(6,6))
sns.kdeplot(x=df["SGPA"],label="sgpa")
sns.kdeplot(x=df["CGPA"],label="cgpa")
plt.legend()
plt.show()
