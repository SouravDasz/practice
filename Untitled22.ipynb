# %% [markdown]
# <a href="https://colab.research.google.com/github/SouravDasz/practice/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d anthonytherrien/dog-vs-cat
# Out:
# Dataset URL: https://www.kaggle.com/datasets/anthonytherrien/dog-vs-cat
# License(s): CC-BY-SA-4.0
# ...
#  86% 311M/360M [00:00<00:00, 819MB/s]
# 100% 360M/360M [00:00<00:00, 683MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/dog-vs-cat.zip', 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense ,Dropout,Conv2D,MaxPooling2D,Flatten
from keras.models import Sequential

# %%
from tensorflow import keras

train_ds = keras.utils.image_dataset_from_directory(
    directory="/content/animals",
    labels="inferred",
    label_mode="int",
    batch_size=32,
    image_size=(256, 256),
    validation_split=0.2,   # 20% data for validation
    subset="training",
    seed=123                # ensures reproducibility
)

val_ds = keras.utils.image_dataset_from_directory(
    directory="/content/animals",
    labels="inferred",
    label_mode="int",
    batch_size=32,
    image_size=(256, 256),
    validation_split=0.2,
    subset="validation",
    seed=123
)
# Out:
# Found 1000 files belonging to 2 classes.
# Using 800 files for training.
# Found 1000 files belonging to 2 classes.
# Using 200 files for validation.

# %%
def process(image,label):
  image=tf.cast(image/255. ,tf.float32)
  return image,label

  dataser=dataser.map(process)

# %%
model=Sequential()
model.add(Conv2D(32,kernel_size=(3,3),padding="valid",activation="relu",input_shape=(256,256,3)))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding="valid"))
model.add(Conv2D(62,kernel_size=(3,3),padding="valid",activation="relu",input_shape=(256,256,3)))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding="valid"))
model.add(Conv2D(62,kernel_size=(3,3),padding="valid",activation="relu",input_shape=(256,256,3)))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding="valid"))

model.add(Flatten())
model.add(Dense(64,activation="relu"))
model.add(Dense(64,activation="relu"))
model.add(Dense(1,activation="sigmoid"))
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 254, 254, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

history=model.fit(train_ds,epochs=10,validation_data=val_ds)
# Out:
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 335ms/step - accuracy: 0.5442 - loss: 48.7002 - val_accuracy: 0.7950 - val_loss: 0.4753
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - accuracy: 0.8544 - loss: 0.4030 - val_accuracy: 0.8200 - val_loss: 0.4174
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 0.9460 - loss: 0.1732 - val_accuracy: 0.8950 - val_loss: 0.2642
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 239ms/step - accuracy: 0.9866 - loss: 0.0568 - val_accuracy: 0.8900 - val_loss: 0.3027
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - accuracy: 0.9931 - loss: 0.0464 - val_accuracy: 0.8400 - val_loss: 0.5737
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 240ms/step - accuracy: 0.9780 - loss: 0.0908 - val_accuracy: 0.8950 - val_loss: 0.3447
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 239ms/step - accuracy: 0.9842 - loss: 0.0347 - val_accuracy: 0.8400 - val_loss: 0.4805
# Epoch 8/10
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["accuracy"],color="red",label="train")
plt.plot(history.history["val_accuracy"],color="blue",label="validation")
plt.legend()
plt.show()

# %%
import cv2

image=cv2.imread("/content/cat.jpg")

# %%
plt.imshow(image)

# %%
image.shape
# Out:
# (350, 700, 3)

# %%
image=cv2.resize(image,(256,256))
image=image.reshape((1,256,256,3))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# array([[0.47402415]], dtype=float32)

# %%
model.predict(image)[0][0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# np.float32(0.47402415)

# %%
prediction = model.predict(image)[0][0]

if prediction >= 0.5:
    print(f"Prediction: Dog (Probability: {prediction:.2f})")
else:
    print(f"Prediction: Cat (Probability: {prediction:.2f})")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Prediction: Cat (Probability: 0.47)

# %%
import os
import cv2

dog_image_dir = "/content/animals/dog"
dog_files = [f for f in os.listdir(dog_image_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

if dog_files:
    # Load the first image found in the dog directory
    sample_dog_image_path = os.path.join(dog_image_dir, dog_files[0])
    dog = cv2.imread(sample_dog_image_path)
    if dog is None:
        print(f"Warning: Failed to load image from {sample_dog_image_path}. Please check the file.")
else:
    print(f"Error: No image files found in {dog_image_dir}. Please ensure dog images are present.")
    dog = None # Ensure dog is None if no images are found

# %%
plt.imshow(dog)

# %%
dog=cv2.resize(dog,(256,256))
dog=dog.reshape((1,256,256,3))

model.predict(dog)[0][0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# array([[0.6853063]], dtype=float32)

# %%
img=model.predict(image)[0][0]
if img >=0.5 :
  print('dog')
else:
  print("cat")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# cat

# %%
def predictor(image):
  image=model.predict(image)
  if image>=0.5:
    return "Dog"
  else :
    return "Cat"

# %%
import pickle
pickle.dump(predictor,open("predictor.pkl","wb"))

# %%
import pickle

# Correct way to open the file
with open("/content/predictor.pkl", "rb") as f:
    predictor = pickle.load(f)
predictor(dog)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 'Dog'
